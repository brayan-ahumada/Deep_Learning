# %%
pip install pandas

# %%
import pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data_frame = pd.read_csv("https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/DataScience/DataSet's/prestamos_records.csv")
data_frame.head(20) # pedir datos en este caso los 20 primeros de la lista
# Out:
#          RECORD_CREATION_DATE  ...  PRESTAMO_INCUMPLIDO
# 0   01May2014:09:24:27.000000  ...                FALSO
# 1   01May2014:09:48:36.000000  ...                FALSO
# 2   01May2014:10:10:36.000000  ...            VERDADERO
# 3   01May2014:10:31:25.000000  ...                FALSO
# 4   01May2014:10:46:54.000000  ...            VERDADERO
# 5   01May2014:11:14:12.000000  ...                FALSO
# 6   01May2014:11:23:11.000000  ...            VERDADERO
# 7   01May2014:11:53:24.000000  ...                FALSO
# 8   01May2014:12:18:53.000000  ...                FALSO
# 9   01May2014:12:32:41.000000  ...                FALSO
# 10  01May2014:12:52:26.000000  ...                FALSO
# 11  01May2014:12:59:04.000000  ...            VERDADERO
# 12  01May2014:13:29:21.000000  ...                FALSO
# 13  01May2014:13:50:52.000000  ...                FALSO
# 14  01May2014:13:57:11.000000  ...                FALSO
# 15  01May2014:14:29:59.000000  ...                FALSO
# ...

# %%
data_frame['nuevacolumna']='' #Para añadir columnas
data_frame.head(3)
# Out:
#         RECORD_CREATION_DATE  ...  nuevacolumna
# 0  01May2014:09:24:27.000000  ...
# 1  01May2014:09:48:36.000000  ...
# 2  01May2014:10:10:36.000000  ...
#
# [3 rows x 8 columns]

# %%
data_frame [data_frame['MONTO_DEL_PRESTAMO']>100] #Para filtrar datos por valores
# Out:
#            RECORD_CREATION_DATE  ...  nuevacolumna
# 0     01May2014:09:24:27.000000  ...
# 1     01May2014:09:48:36.000000  ...
# 2     01May2014:10:10:36.000000  ...
# 3     01May2014:10:31:25.000000  ...
# 4     01May2014:10:46:54.000000  ...
# ...                         ...  ...           ...
# 7995  07May2015:16:04:54.000000  ...
# 7996  07May2015:16:38:22.000000  ...
# 7997  07May2015:17:04:07.000000  ...
# 7998  07May2015:17:37:18.000000  ...
# 7999  07May2015:17:52:58.000000  ...
#
# [8000 rows x 8 columns]
